# %% [markdown]
# # MedRAG: Medical Research Answer Graph
#
# Graph RAG (MedRAG). This technique improves LLM performance in the medical domain by response queries with grounded source citations and clear interpretations of medical terminology, boosting the transparency and interpretability of the results. This approach involves a three-tier hierarchical graph construction method. Initially, we use documents provided by users as our top-level source to extract entities. These entities are then linked to a second level consisting of more basic entities previously abstracted from credible medical books and papers.
#
# ![image.png](attachment:image.png)
#
# Ref: https://arxiv.org/html/2408.04187

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core.response.notebook_utils import display_source_node
from llama_index.core.node_parser import (
    SentenceSplitter,
    SemanticSplitterNodeParser,
    SemanticDoubleMergingSplitterNodeParser,
    LanguageConfig,
)
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI

from llama_index.core import SimpleDirectoryReader
import os
from dotenv import load_dotenv

load_dotenv()  # take environment variables from .env.
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %%
from llama_index.core import SimpleDirectoryReader

# load documents
documents = SimpleDirectoryReader(input_files=["spec.txt"]).load_data()

# %%
embed_model = OpenAIEmbedding()
llm = OpenAI(model="gpt-4o-mini")

# %%
# !pip install llama-index-node-parser-topic
# Out:
# Collecting llama-index-node-parser-topic
#   Downloading llama_index_node_parser_topic-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in ./.venv/lib/python3.10/site-packages (from llama-index-node-parser-topic) (0.11.14)
# Requirement already satisfied: PyYAML>=6.0.1 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.10.7)
# Requirement already satisfied: dataclasses-json in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2024.9.0)
# Requirement already satisfied: httpx in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.3)
# Requirement already satisfied: nltk>3.8.1 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.9.0)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (4.0.3)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in ./.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (3.22.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (4.6.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.0.5)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (24.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-node-parser-topic) (1.2.2)
# Downloading llama_index_node_parser_topic-0.1.0-py3-none-any.whl (6.5 kB)
# Installing collected packages: llama-index-node-parser-topic
# Successfully installed llama-index-node-parser-topic-0.1.0

# %%
from llama_index.node_parser.topic import TopicNodeParser

# %%
node_parser = TopicNodeParser.from_defaults(
    llm=llm,
    max_chunk_size=1000,
    similarity_method="llm",  # can be "llm" or "embedding"
    window_size=5,  # paper suggests window_size=5
)

# also baseline splitter
base_splitter = SentenceSplitter(chunk_size=512)

# %%
nodes = node_parser.get_nodes_from_documents(documents, show_progress=True)
# Out:
# Parsing nodes: 100%|██████████| 1/1 [09:14<00:00, 554.86s/it]

# %%
print(nodes[0].get_content())
# Out:
# Tuổi Bính Thìn - 1976 được đánh giá là tốt. Tuổi Đinh Hợi - 1947 được đánh giá là tốt. Tuổi Nhâm Tý - 1972 được đánh giá là tốt. Tuổi Quý Mùi - 2003 được đánh giá là tốt. Tuổi Nhâm Ngọ - 2002 được đánh giá là tốt. Tuổi Canh Tý - 1960 được đánh giá là tốt. Tuổi Nhâm Ngọ - 1942 được đánh giá là tốt. Tuổi Quý Mùi - 1943 được đánh giá là tốt. Tuổi Tân Mão - 1951 được đánh giá là tốt. Tuổi Kỷ Mão - 1939 được đánh giá là tốt.

# %%
print("Number of nodes:", len(nodes))
# Out:
# Number of nodes: 181

# %%
print('node 3:', nodes[7].get_content())
# Out:
# node 3: Địa chi tuổi xông nhà là Thìn đạt Tam Hợp với địa chi Thìn của năm Giáp Thìn. Địa chi tuổi xông nhà là Thìn đạt Tam Hợp với địa chi Thìn của năm Giáp Thìn được đánh giá là rất tốt.
