# %% [markdown]
# # Fine-tuning a gpt-3.5 ReAct Agent on Better Chain of Thought
#
# https://docs.llamaindex.ai/en/stable/examples/finetuning/react_agent/react_agent_finetune/

# %%
# %pip install llama-index-finetuning
# %pip install llama-index-finetuning-callbacks
# %pip install llama-index-llms-openai
# Out:
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 821.6 kB/s eta 0:00:001m812.0 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 1.7 MB/s eta 0:00:002.2 MB/s eta 0:00:01
# ...
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# ...

# %%
from llama_index.core import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
)
from llama_index.llms.openai import OpenAI

from llama_index.core.tools import QueryEngineTool, ToolMetadata

# %%
llm_4 = OpenAI(model="gpt-4o-mini", temperature=0.3)

# %%
try:
    storage_context = StorageContext.from_defaults(
        persist_dir="../data"
    )
    luan_giai_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/june"
    )
    june_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/sept"
    )
    sept_index = load_index_from_storage(storage_context)

    index_loaded = True
except:
    index_loaded = False
