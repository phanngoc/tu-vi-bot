# %%
# %pip install llama-index-llms-openai
# Out:
# Requirement already satisfied: llama-index-llms-openai in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (0.2.9)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (0.11.14)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (1.50.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.10.7)
# Requirement already satisfied: dataclasses-json in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.5.0)
# Requirement already satisfied: sniffio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama-index-llms-openai
# !pip install llama-index
import nest_asyncio

nest_asyncio.apply()
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.core.response.pprint_utils import pprint_response
from llama_index.llms.openai import OpenAI

from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine
# Out:
# Requirement already satisfied: llama-index-llms-openai in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (0.2.9)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (0.11.14)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (1.50.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.10.7)
# Requirement already satisfied: dataclasses-json in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.5.0)
# Requirement already satisfied: sniffio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (0.11.14)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.3.4)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.14 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.11.14)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.9 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.9)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.1)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.2.2)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.50.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (3.10.7)
# Requirement already satisfied: dataclasses-json in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2024.9.0)
# Requirement already satisfied: httpx in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.1.0)
# Requirement already satisfied: pandas in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.6)
# Requirement already satisfied: click in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (2024.9.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (4.6.0)
# Requirement already satisfied: certifi in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.0.5)
# Requirement already satisfied: idna in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.10)
# Requirement already satisfied: sniffio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.2.2)
# Requirement already satisfied: packaging>=17.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)

# %%
# !mkdir -p 'data/10q/'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_march_2022.pdf' -O 'data/10q/uber_10q_march_2022.pdf'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_june_2022.pdf' -O 'data/10q/uber_10q_june_2022.pdf'
# !wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_sept_2022.pdf' -O 'data/10q/uber_10q_sept_2022.pdf'
# Out:
# --2024-10-01 21:40:32--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_march_2022.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8003::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1260185 (1.2M) [application/octet-stream]
# Saving to: ‘data/10q/uber_10q_march_2022.pdf’
#
# data/10q/uber_10q_m 100%[===================>]   1.20M   496KB/s    in 2.5s
#
# 2024-10-01 21:40:37 (496 KB/s) - ‘data/10q/uber_10q_march_2022.pdf’ saved [1260185/1260185]
#
# --2024-10-01 21:40:37--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_june_2022.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8003::154, 2606:50c0:8002::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1238483 (1.2M) [application/octet-stream]
# Saving to: ‘data/10q/uber_10q_june_2022.pdf’
#
# data/10q/uber_10q_j 100%[===================>]   1.18M   270KB/s    in 4.9s
#
# 2024-10-01 21:40:44 (248 KB/s) - ‘data/10q/uber_10q_june_2022.pdf’ saved [1238483/1238483]
#
# --2024-10-01 21:40:45--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/10q/uber_10q_sept_2022.pdf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8002::154, 2606:50c0:8003::154, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8002::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1178622 (1.1M) [application/octet-stream]
# Saving to: ‘data/10q/uber_10q_sept_2022.pdf’
#
# data/10q/uber_10q_s 100%[===================>]   1.12M  1.06MB/s    in 1.1s
#
# 2024-10-01 21:40:46 (1.06 MB/s) - ‘data/10q/uber_10q_sept_2022.pdf’ saved [1178622/1178622]

# %%
march_2022 = SimpleDirectoryReader(
    input_files=["./data/10q/uber_10q_march_2022.pdf"]
).load_data()
june_2022 = SimpleDirectoryReader(
    input_files=["./data/10q/uber_10q_june_2022.pdf"]
).load_data()
sept_2022 = SimpleDirectoryReader(
    input_files=["./data/10q/uber_10q_sept_2022.pdf"]
).load_data()

march_index = VectorStoreIndex.from_documents(march_2022)
june_index = VectorStoreIndex.from_documents(june_2022)
sept_index = VectorStoreIndex.from_documents(sept_2022)

# %%
march_engine = march_index.as_query_engine(similarity_top_k=3)
june_engine = june_index.as_query_engine(similarity_top_k=3)
sept_engine = sept_index.as_query_engine(similarity_top_k=3)

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=sept_engine,
        metadata=ToolMetadata(
            name="sept_22",
            description=(
                "Provides information about Uber quarterly financials ending"
                " September 2022"
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=june_engine,
        metadata=ToolMetadata(
            name="june_22",
            description=(
                "Provides information about Uber quarterly financials ending"
                " June 2022"
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=march_engine,
        metadata=ToolMetadata(
            name="march_22",
            description=(
                "Provides information about Uber quarterly financials ending"
                " March 2022"
            ),
        ),
    ),
]

# %%
s_engine = SubQuestionQueryEngine.from_defaults(
    query_engine_tools=query_engine_tools
)

# %%
response = s_engine.query(
    "Analyze Uber revenue growth over the latest two quarter filings"
)
# Out:
# Generated 2 sub questions.
# [sept_22] Q: What was Uber's revenue in the latest quarter ending September 2022?
# [june_22] Q: What was Uber's revenue in the quarter ending June 2022?
# [sept_22] A: Uber's revenue in the latest quarter ending September 2022 was $8.3 billion.
# [june_22] A: Uber's revenue in the quarter ending June 2022 was $8,073 million.
