# %% [markdown]
# # Agent use workflow
#
# This notebook demonstrates the use of the LlamaIndex library to create and query a vector store index from documents. It includes functions to convert solar dates to lunar dates, assign stars to astrological charts based on birth details, and execute a retrieval-augmented generation (RAG) workflow. The workflow involves ingesting documents, extracting information, retrieving relevant nodes, reranking them, and synthesizing a response using a language model. The notebook also includes an example of running the workflow asynchronously.
#
# https://docs.llamaindex.ai/en/stable/examples/workflow/react_agent/

# %%
# %pip install llama-index-finetuning
# %pip install llama-index-finetuning-callbacks
# %pip install llama-index-llms-openai
# %pip install "openinference-instrumentation-llama-index>=3.0.0" "opentelemetry-proto>=1.12.0" opentelemetry-exporter-otlp opentelemetry-sdk
# Out:
# Requirement already satisfied: llama-index-finetuning in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (0.2.1)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (0.11.14)
# Requirement already satisfied: llama-index-embeddings-adapter<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (0.2.2)
# Requirement already satisfied: llama-index-llms-azure-openai<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (0.2.1)
# Requirement already satisfied: llama-index-llms-mistralai<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (0.2.5)
# Requirement already satisfied: llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (0.2.1)
# Requirement already satisfied: sentence-transformers>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-finetuning) (3.1.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.10.7)
# Requirement already satisfied: dataclasses-json in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2024.9.0)
# Requirement already satisfied: httpx in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.16.0)
# Requirement already satisfied: torch>=2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-embeddings-adapter<0.3.0,>=0.2.0->llama-index-finetuning) (2.4.1)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.18.0)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (0.2.9)
# Requirement already satisfied: mistralai>=1.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-mistralai<0.3.0,>=0.2.0->llama-index-finetuning) (1.1.0)
# Requirement already satisfied: cohere<6.0.0,>=5.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (5.11.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->llama-index-finetuning) (4.45.1)
# Requirement already satisfied: scikit-learn in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->llama-index-finetuning) (1.5.2)
# Requirement already satisfied: scipy in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->llama-index-finetuning) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sentence-transformers>=2.3.0->llama-index-finetuning) (0.25.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (4.0.3)
# Requirement already satisfied: azure-core>=1.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.31.0)
# Requirement already satisfied: cryptography>=2.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (43.0.1)
# Requirement already satisfied: msal>=1.30.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.31.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.2.0)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.35.31)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.9.7)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.9.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.23.4)
# Requirement already satisfied: sagemaker<3.0.0,>=2.232.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.232.1)
# Requirement already satisfied: tokenizers<1,>=0.15 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.20.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.32.0.20240914)
# Requirement already satisfied: anyio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (4.6.0)
# Requirement already satisfied: certifi in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.0.5)
# Requirement already satisfied: idna in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.10)
# Requirement already satisfied: sniffio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.14.0)
# Requirement already satisfied: filelock in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->sentence-transformers>=2.3.0->llama-index-finetuning) (3.16.1)
# Requirement already satisfied: packaging>=20.9 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->sentence-transformers>=2.3.0->llama-index-finetuning) (24.1)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai<0.3.0,>=0.2.1->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.50.2)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from mistralai>=1.0.0->llama-index-llms-mistralai<0.3.0,>=0.2.0->llama-index-finetuning) (0.2.0)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from mistralai>=1.0.0->llama-index-llms-mistralai<0.3.0,>=0.2.0->llama-index-finetuning) (1.0.6)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from mistralai>=1.0.0->llama-index-llms-mistralai<0.3.0,>=0.2.0->llama-index-finetuning) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from python-dateutil==2.8.2->mistralai>=1.0.0->llama-index-llms-mistralai<0.3.0,>=0.2.0->llama-index-finetuning) (1.16.0)
# Requirement already satisfied: click in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (8.1.7)
# Requirement already satisfied: joblib in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.1.1)
# Requirement already satisfied: sympy in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from torch>=2.0.0->llama-index-embeddings-adapter<0.3.0,>=0.2.0->llama-index-finetuning) (1.13.3)
# Requirement already satisfied: jinja2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from torch>=2.0.0->llama-index-embeddings-adapter<0.3.0,>=0.2.0->llama-index-finetuning) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=2.3.0->llama-index-finetuning) (0.4.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (3.22.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.3.0->llama-index-finetuning) (3.5.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.31 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.35.31)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.10.2)
# Requirement already satisfied: cffi>=1.12 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (2.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (2.10.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.1->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai<0.3.0,>=0.2.1->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (0.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-finetuning) (1.2.2)
# Requirement already satisfied: cloudpickle==2.2.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.2.1)
# Requirement already satisfied: docker in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (7.1.0)
# Requirement already satisfied: google-pasta in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (6.11.0)
# Requirement already satisfied: jsonschema in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (4.23.0)
# Requirement already satisfied: pandas in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.2.3)
# Requirement already satisfied: pathos in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.3.3)
# Requirement already satisfied: platformdirs in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (4.3.6)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (4.25.5)
# Requirement already satisfied: psutil in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (6.0.0)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.0.9)
# Requirement already satisfied: schema in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->llama-index-embeddings-adapter<0.3.0,>=0.2.0->llama-index-finetuning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sympy->torch>=2.0.0->llama-index-embeddings-adapter<0.3.0,>=0.2.0->llama-index-finetuning) (1.3.0)
# Requirement already satisfied: pycparser in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.15.0->llama-index-llms-azure-openai<0.3.0,>=0.2.0->llama-index-finetuning) (2.22)
# Requirement already satisfied: zipp>=0.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (3.20.2)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (13.8.1)
# Requirement already satisfied: mock<5.0,>4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from jsonschema->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.20.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pandas->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pandas->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2024.2)
# Requirement already satisfied: ppft>=1.7.6.9 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.9 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.3.9)
# Requirement already satisfied: pox>=0.3.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pathos->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.70.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker<3.0.0,>=2.232.1->cohere<6.0.0,>=5.1.1->llama-index-postprocessor-cohere-rerank<0.3.0,>=0.2.0->llama-index-finetuning) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement llama-index-finetuning-callbacks (from versions: none)
# ERROR: No matching distribution found for llama-index-finetuning-callbacks
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (0.2.9)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (0.11.14)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-llms-openai) (1.50.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.10.7)
# Requirement already satisfied: dataclasses-json in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.0)
# Requirement already satisfied: httpx in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (0.5.0)
# Requirement already satisfied: sniffio in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->llama-index-llms-openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index-llms-openai) (24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openinference-instrumentation-llama-index>=3.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (3.0.2)
# Requirement already satisfied: opentelemetry-proto>=1.12.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (1.27.0)
# Requirement already satisfied: opentelemetry-sdk in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (1.27.0)
# Requirement already satisfied: openinference-instrumentation>=0.1.12 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (0.1.18)
# Requirement already satisfied: openinference-semantic-conventions>=0.1.9 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (0.1.10)
# Requirement already satisfied: opentelemetry-api in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (0.48b0)
# Requirement already satisfied: typing-extensions in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (4.12.2)
# Requirement already satisfied: wrapt in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from openinference-instrumentation-llama-index>=3.0.0) (1.16.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-proto>=1.12.0) (4.25.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp) (1.27.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp) (1.2.14)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp) (1.65.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp) (1.66.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp) (1.27.0)
# Requirement already satisfied: requests~=2.7 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp) (2.32.3)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-api->openinference-instrumentation-llama-index>=3.0.0) (6.11.0)
# Requirement already satisfied: setuptools>=16.0 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation->openinference-instrumentation-llama-index>=3.0.0) (58.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api->openinference-instrumentation-llama-index>=3.0.0) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ngocp/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.27.0->opentelemetry-exporter-otlp) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.core import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
)
from llama_index.llms.openai import OpenAI

from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.agent import ReActAgent

# %%
llm_4 = OpenAI(model="gpt-4o-mini")

# %%
def create_and_load_index(name = ''):
    persist_dir = "./storage/" + name
    try:
        storage_context = StorageContext.from_defaults(
            persist_dir=persist_dir,
        )
        tu_vi_index = load_index_from_storage(storage_context)
        index_loaded = True
    except:
        index_loaded = False
    
    if not index_loaded:
        docs = SimpleDirectoryReader(
            input_files=["../data/" + name + ".md"],
        ).load_data()
        tu_vi_index = VectorStoreIndex.from_documents(docs)
        tu_vi_index.storage_context.persist(persist_dir)

    return tu_vi_index

# %%
# loai_cung_engine = loai_cung_index.as_query_engine(similarity_top_k=3)
# cac_buoc_luan_doan_la_so_tu_vi_engine = cac_buoc_luan_doan_la_so_tu_vi_index.as_query_engine(similarity_top_k=3)
# tuoi_xong_dat_engine = tuoi_xong_dat_index.as_query_engine(similarity_top_k=3)

# %% [markdown]
# ## Hàm luận từ ngày tháng năm sinh.

# %%
from datetime import datetime

def an_sao_tuvi(day, month, year, hour):
    # Thông tin cơ bản từ ngày tháng năm sinh
    can = ['Giáp', 'Ất', 'Bính', 'Đinh', 'Mậu', 'Kỷ', 'Canh', 'Tân', 'Nhâm', 'Quý']
    chi = ['Tý', 'Sửu', 'Dần', 'Mão', 'Thìn', 'Tỵ', 'Ngọ', 'Mùi', 'Thân', 'Dậu', 'Tuất', 'Hợi']
    cung_names = ['Mệnh', 'Phụ Mẫu', 'Phúc Đức', 'Điền Trạch', 'Quan Lộc', 'Nô Bộc', 
                  'Thiên Di', 'Tật Ách', 'Tài Bạch', 'Tử Tức', 'Phu Thê', 'Huynh Đệ']
    
    # Xác định Thiên Can và Địa Chi từ năm sinh
    can_index = (year % 10)
    chi_index = (year % 12)
    thien_can = can[can_index]
    dia_chi = chi[chi_index]
    
    # Tính Cục dựa vào năm sinh
    cuc_mapping = {
        'Kim': ['Canh', 'Tân'],
        'Mộc': ['Giáp', 'Ất'],
        'Thủy': ['Nhâm', 'Quý'],
        'Hỏa': ['Bính', 'Đinh'],
        'Thổ': ['Mậu', 'Kỷ']
    }
    cuc = None
    for key, values in cuc_mapping.items():
        print('cuc_mapping:', key, values)
        if thien_can in values:
            cuc = key
            break

    # An các cung dựa vào giờ sinh
    gio_mapping = {
        'Tý': 0, 'Sửu': 1, 'Dần': 2, 'Mão': 3,
        'Thìn': 4, 'Tỵ': 5, 'Ngọ': 6, 'Mùi': 7,
        'Thân': 8, 'Dậu': 9, 'Tuất': 10, 'Hợi': 11
    }
    gio_sinh = list(gio_mapping.keys())[hour % 12]
    
    # Bản đồ chi đến các cung trong lá số
    cung_chi_mapping = {
        'Tý': 'Mệnh', 'Sửu': 'Phụ Mẫu', 'Dần': 'Phúc Đức', 'Mão': 'Điền Trạch',
        'Thìn': 'Quan Lộc', 'Tỵ': 'Nô Bộc', 'Ngọ': 'Thiên Di', 'Mùi': 'Tật Ách',
        'Thân': 'Tài Bạch', 'Dậu': 'Tử Tức', 'Tuất': 'Phu Thê', 'Hợi': 'Huynh Đệ'
    }
    
    # An các sao chính tinh
    chinh_tinh = {
        'Tử Vi': 'Thìn', 'Thiên Phủ': 'Tuất', 'Thái Dương': 'Dần', 'Thái Âm': 'Hợi',
        'Thiên Cơ': 'Sửu', 'Thiên Lương': 'Ngọ', 'Vũ Khúc': 'Thân', 'Thiên Đồng': 'Tý',
        'Cự Môn': 'Dậu', 'Liêm Trinh': 'Mão', 'Thất Sát': 'Mùi', 'Phá Quân': 'Tỵ',
        'Tham Lang': 'Dậu'
    }
    
    # Phụ tinh cơ bản
    phu_tinh = {
        'Hóa Khoa': 'Mệnh', 'Hóa Quyền': 'Quan Lộc', 'Hóa Lộc': 'Tài Bạch', 'Hóa Kỵ': 'Phu Thê'
    }
    
    # Kết quả an sao
    sao_cung = {cung: [] for cung in cung_names}
    
    # An các chính tinh vào các cung
    for sao, chi_name in chinh_tinh.items():
        cung = cung_chi_mapping[chi_name]  # Lấy tên cung từ chi
        # print('an_sao_tuvi:chinh_tinh', cung, sao, chi_name)
        sao_cung[cung].append(sao)
    
    # An các phụ tinh vào các cung
    for sao, cung in phu_tinh.items():
        sao_cung[cung].append(sao)
    
    response = ""
    response += f"Lá số cho {day}/{month}/{year} giờ {gio_sinh}\n"
    response += f"Thiên Can: {thien_can}, Địa Chi: {dia_chi}, Cục: {cuc}\n"
    for cung, sao_list in sao_cung.items():
        response += f"{cung}: {', '.join(sao_list) if sao_list else 'Không có sao'}\n"

    # Kết quả cuối cùng
    print(f"Lá số cho {day}/{month}/{year} giờ {gio_sinh}")
    print(f"Thiên Can: {thien_can}, Địa Chi: {dia_chi}, Cục: {cuc}")
    for cung, sao_list in sao_cung.items():
        print(f"{cung}: {', '.join(sao_list) if sao_list else 'Không có sao'}")
    
    return response

an_sao_tuvi(1, 10, 1996, 4)
# Out:
# cuc_mapping: Kim ['Canh', 'Tân']
# Lá số cho 1/10/1996 giờ Thìn
# Thiên Can: Canh, Địa Chi: Thìn, Cục: Kim
# Mệnh: Thiên Đồng, Hóa Khoa
# Phụ Mẫu: Thiên Cơ
# Phúc Đức: Thái Dương
# Điền Trạch: Liêm Trinh
# Quan Lộc: Tử Vi, Hóa Quyền
# Nô Bộc: Phá Quân
# Thiên Di: Thiên Lương
# Tật Ách: Thất Sát
# Tài Bạch: Vũ Khúc, Hóa Lộc
# Tử Tức: Cự Môn, Tham Lang
# Phu Thê: Thiên Phủ, Hóa Kỵ
# Huynh Đệ: Thái Âm
# 'Lá số cho 1/10/1996 giờ Thìn\nThiên Can: Canh, Địa Chi: Thìn, Cục: Kim\nMệnh: Thiên Đồng, Hóa Khoa\nPhụ Mẫu: Thiên Cơ\nPhúc Đức: Thái Dương\nĐiền Trạch: Liêm Trinh\nQuan Lộc: Tử Vi, Hóa Quyền\nNô Bộc: Phá Quân\nThiên Di: Thiên Lương\nTật Ách: Thất Sát\nTài Bạch: Vũ Khúc, Hóa Lộc\nTử Tức: Cự Môn, Tham Lang\nPhu Thê: Thiên Phủ, Hóa Kỵ\nHuynh Đệ: Thái Âm\n'

# %%
from llama_index.core.tools import BaseTool, FunctionTool
from lunarcalendar import Converter, Solar

def convert_to_lunar(year, month, day):
    solar = Solar(year, month, day)
    lunar = Converter.Solar2Lunar(solar)
    return lunar

def fn_an_sao(birthday: str, hour: str):
    """Trích xuất birthday[date + hour] từ text người dùng nhập và gán sao theo các [cung mệnh, chính tinh và phụ tinh]"""
    print('fn_an_sao:', birthday, hour)
    date_obj = datetime.strptime(birthday, "%d/%m/%Y")
    hour = hour.split(':')[0]
    hour_int = int(hour)

    lunar_date = convert_to_lunar(date_obj.year, date_obj.month, date_obj.day)

    results = an_sao_tuvi(lunar_date.day, lunar_date.month, lunar_date.year, hour_int)

    return results

an_sao_tool = FunctionTool.from_defaults(fn=fn_an_sao, name="fn_an_sao")

# query_engine_tools = [
#     an_sao_tool,
#     QueryEngineTool(
#         query_engine=loai_cung_engine,
#         metadata=ToolMetadata(
#             name="loai_cung",
#             description=(
#                 "các loại cung được sử dụng để phân tích và dự đoán tính cách, cuộc đời của con người"
#                 "Use a detailed plain text question as input to the tool."
#             ),
#         ),
#     ),
#     QueryEngineTool(
#         query_engine=cac_buoc_luan_doan_la_so_tu_vi_engine,
#         metadata=ToolMetadata(
#             name="cac_buoc_luan_doan_la_so_tu_vi",
#             description=(
#                 "Phục vụ thông tin về các bước luận đoán lá số tử vi."
#                 "Use a detailed plain text question as input to the tool."
#             ),
#         ),
#     ),
#     QueryEngineTool(
#         query_engine=tuoi_xong_dat_engine,
#         metadata=ToolMetadata(
#             name="tuoi_xong_dat",
#             description=(
#                 "Phục vụ thông tin về tuổi xông đất."
#                 "Use a detailed plain text question as input to the tool."
#             ),
#         ),
#     ),
# ]

# %%
from llama_index.core.workflow import Event
from llama_index.core.schema import NodeWithScore


class ExtractEvent(Event):
    """Result of running extraction"""


class RetrieverEvent(Event):
    """Result of running retrieval"""

    nodes: list[NodeWithScore]


class RerankEvent(Event):
    """Result of running reranking on retrieved nodes"""

    nodes: list[NodeWithScore]

# %%
from llama_index.core.response_synthesizers import CompactAndRefine
from llama_index.core.postprocessor.llm_rerank import LLMRerank
from llama_index.core.workflow import (
    Context,
    Workflow,
    StartEvent,
    StopEvent,
    step,
)

from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.agent.openai import OpenAIAgent

class RAGWorkflow(Workflow):
    @step
    async def ingest(self, ctx: Context, ev: StartEvent) -> StopEvent | None:
        """Entry point to ingest a document, triggered by a StartEvent with `dirname`."""
        print("ingest data")
        dirname = ev.get("dirname")
        docs = SimpleDirectoryReader(
            input_dir=[dirname],
        ).load_data()
        tu_vi_index = VectorStoreIndex.from_documents(docs)
        return StopEvent(result=tu_vi_index)

    @step
    async def extract_an_sao(self, ctx: Context, ev: StartEvent) -> ExtractEvent | None:
        """Entry point to extract an sao, triggered by a StartEvent with `query`."""
        query = ev.get("query")
        await ctx.set("query", query)
        print('extract_an_sao:', query)
        llm = OpenAI(model="gpt-4o-mini")
        # initialize agent
        agent = OpenAIAgent.from_tools(
            [an_sao_tool],
            max_function_calls=1,
            llm=llm,
            verbose=True,
        )

        res_an_sao = agent.chat(query)
        print('res_an_sao:', res_an_sao)
        return ExtractEvent(result=res_an_sao)

    # @step
    # async def start_query(
    #     self, ctx: Context, ev: StartEvent
    # ) -> StopEvent | None:
    #     """Entry point to clean query, triggered by a StartEvent with `query`."""
    #     query = ev.get("query")
    #     print('clean_query:', query)
    #     return StopEvent(result=query)

    @step
    async def retrieve(
        self, ctx: Context, ev: ExtractEvent
    ) -> RetrieverEvent | None:
        "Entry point for RAG, triggered by a StartEvent with `query`."
        query = ctx.get("query")
        index = ev.get("index")

        print(f"Query the database with: {query}, {index}")

        if not query:
            print("Query is empty, please provide a query!")
            return None
        print('start an sao:', query)
        res_an_sao = an_sao_tool.execute(query)
        print('res_an_sao:', res_an_sao)
        # store the query in the global context
        # await ctx.set("query", query)
        await ctx.set("res_an_sao", res_an_sao)

        # get the index from the global context
        if index is None:
            print("Index is empty, load some documents before querying!")
            return None

        print("Retrieving nodes...", query)
        retriever = index.as_retriever(similarity_top_k=2)
        nodes = retriever.retrieve(query)
        print(f"Retrieved {len(nodes)} nodes.")
        return RetrieverEvent(nodes=nodes)

    @step
    async def rerank(self, ctx: Context, ev: RetrieverEvent) -> RerankEvent:
        # Rerank the nodes
        print("Reranking nodes...")
        ranker = LLMRerank(
            choice_batch_size=5, top_n=3, llm=OpenAI(model="gpt-4o-mini")
        )
        
        query = await ctx.get("query", default=None)
        res_an_sao = await ctx.get("res_an_sao", default=None)
        query_str = f"{query} {res_an_sao}"

        # print(await ctx.get("query", default=None), flush=True)
        new_nodes = ranker.postprocess_nodes(
            ev.nodes, query_str=query_str
        )
        print(f"Reranked nodes to {len(new_nodes)}")
        return RerankEvent(nodes=new_nodes)

    @step
    async def synthesize(self, ctx: Context, ev: RerankEvent) -> StopEvent:
        """Return a streaming response using reranked nodes."""
        llm = OpenAI(model="gpt-4o-mini")
        summarizer = CompactAndRefine(llm=llm, streaming=True, verbose=True)
        query = await ctx.get("query", default=None)
        res_an_sao = await ctx.get("res_an_sao", default=None)
        query_str = f"{query} {res_an_sao}"
        print("Synthesizing response...")
        print(f"Query: {query_str}")

        response = await summarizer.asynthesize(query_str, nodes=ev.nodes)
        return StopEvent(result=response)

# %%
import nest_asyncio
import asyncio

# Apply the nest_asyncio patch
nest_asyncio.apply()

async def main():
    wf = RAGWorkflow()
    # Start the workflow
    await wf.run(tu_vi="lá số cho 1/10/1996 giờ 4")

    index = await wf.run(dirname="../data/")
    await wf.run(query="lá số cho 1/10/1996 giờ 4", index=index)
    print("Workflow completed.")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# extract_an_sao: None
# ingest data
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[18], line 17
#      14     print("Workflow completed.")
#      16 if __name__ == "__main__":
# ---> 17     asyncio.run(main())
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/asyncio/tasks.py:234, in Task.__step(***failed resolving arguments***)
#     232         result = coro.send(None)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#     236     if self._must_cancel:
#     237         # Task is cancelled right before coro stops.
#
# Cell In[18], line 10, in main()
#       8 wf = RAGWorkflow()
#       9 # Start the workflow
# ---> 10 await wf.run(tu_vi="lá số cho 1/10/1996 giờ 4")
#      12 index = await wf.run(dirname="../data/")
#      13 await wf.run(query="lá số cho 1/10/1996 giờ 4", index=index)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     302 def __wakeup(self, future):
#     303     try:
# --> 304         future.result()
#     305     except BaseException as exc:
#     306         # This may also be a cancellation.
#     307         self.__step(exc)
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/workflow/workflow.py:338, in Workflow.run.<locals>._run_workflow()
#     336 if exception_raised:
#     337     ctx.write_event_to_stream(StopEvent())
# --> 338     raise exception_raised
#     340 if not we_done:
#     341     msg = f"Operation timed out after {self._timeout} seconds"
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/workflow/workflow.py:219, in Workflow._start.<locals>._task(name, queue, step, config)
#     217 except Exception as e:
#     218     if config.retry_policy is None:
# --> 219         raise e from None
#     221     delay = config.retry_policy.next(
#     222         retry_start_at + time.time(), attempts, e
#     223     )
#     224     if delay is None:
#     225         # We're done retrying
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/workflow/workflow.py:215, in Workflow._start.<locals>._task(name, queue, step, config)
#     213 while True:
#     214     try:
# --> 215         new_ev = await instrumented_step(**kwargs)
#     216         break  # exit the retrying loop
#     217     except Exception as e:
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:297, in Dispatcher.span.<locals>.async_wrapper(func, instance, args, kwargs)
#     289 self.span_enter(
#     290     id_=id_,
#     291     bound_args=bound_args,
#    (...)
#     294     tags=tags,
#     295 )
#     296 try:
# --> 297     result = await func(*args, **kwargs)
#     298 except BaseException as e:
#     299     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# Cell In[17], line 42, in RAGWorkflow.extract_an_sao(self, ctx, ev)
#      34 # initialize agent
#      35 agent = OpenAIAgent.from_tools(
#      36     [an_sao_tool],
#      37     max_function_calls=1,
#      38     llm=llm,
#      39     verbose=True,
#      40 )
# ---> 42 res_an_sao = agent.chat(query)
#      43 print('res_an_sao:', res_an_sao)
#      44 return ExtractEvent(result=res_an_sao)
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:647, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     642     tool_choice = self.default_tool_choice
#     643 with self.callback_manager.event(
#     644     CBEventType.AGENT_STEP,
#     645     payload={EventPayload.MESSAGES: [message]},
#     646 ) as e:
# --> 647     chat_response = self._chat(
#     648         message=message,
#     649         chat_history=chat_history,
#     650         tool_choice=tool_choice,
#     651         mode=ChatResponseMode.WAIT,
#     652     )
#     653     assert isinstance(chat_response, AgentChatResponse)
#     654     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:573, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     571 if chat_history is not None:
#     572     self.memory.set(chat_history)
# --> 573 task = self.create_task(message)
#     575 result_output = None
#     576 dispatcher.event(AgentChatWithStepStartEvent(user_msg=message))
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:265, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     257 self.span_enter(
#     258     id_=id_,
#     259     bound_args=bound_args,
#    (...)
#     262     tags=tags,
#     263 )
#     264 try:
# --> 265     result = func(*args, **kwargs)
#     266 except BaseException as e:
#     267     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/llama_index/core/agent/runner/base.py:319, in AgentRunner.create_task(self, input, **kwargs)
#     316         extra_state = self.init_task_state_kwargs
#     318 callback_manager = kwargs.pop("callback_manager", self.callback_manager)
# --> 319 task = Task(
#     320     input=input,
#     321     memory=self.memory,
#     322     extra_state=extra_state,
#     323     callback_manager=callback_manager,
#     324     **kwargs,
#     325 )
#     326 # # put input into memory
#     327 # self.memory.put(ChatMessage(content=input, role=MessageRole.USER))
#     328
#     329 # get initial step from task, and put it in the step queue
#     330 initial_step = self.agent_worker.initialize_step(task)
#
# File ~/Documents/projects/tu-vi-bot/.venv/lib/python3.10/site-packages/pydantic/main.py:212, in BaseModel.__init__(self, **data)
#     210 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     211 __tracebackhide__ = True
# --> 212 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     213 if self is not validated_self:
#     214     warnings.warn(
#     215         'A custom validator is returning a value other than `self`.\n'
#     216         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     217         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     218         category=None,
#     219     )
#
# ValidationError: 1 validation error for Task
# input
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.9/v/string_type
